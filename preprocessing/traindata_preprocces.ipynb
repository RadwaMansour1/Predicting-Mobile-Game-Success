# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
from typing import List

# label Enconder
from sklearn.preprocessing import LabelEncoder
# Scaling
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
# splitting
from sklearn.model_selection import train_test_split

from sklearn.feature_selection import SelectKBest, f_classif

from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load Dataset

# %%
# Load the dataset
# specify the file path to the CSV file
file_path = "D:\Programming\College\ML\Project\Project\Milestone 2/Data\games-classification-dataset.csv"

dataset = pd.read_csv(file_path,
                      parse_dates=['Original Release Date','Current Version Release Date'], dayfirst=True)

# %%
dataset.head()
# Out:
#                                                  URL          ID  \
# 0  https://apps.apple.com/us/app/heir-of-light/id...  1264483706
# 1  https://apps.apple.com/us/app/endgame-eurasia/...   607705356
# 2  https://apps.apple.com/us/app/free-solitaire/i...   627491527
# 3  https://apps.apple.com/us/app/draft-trainer/id...   430252596
# 4  https://apps.apple.com/us/app/rogue-knight-inf...  1115082819
#
#                            Name                       Subtitle  \
# 0                 HEIR OF LIGHT               Dark Fantasy RPG
# 1               Endgame:Eurasia                            NaN
# 2               Free Solitaire+                            NaN
# 3                 Draft Trainer                            NaN
# 4  Rogue Knight: Infested Lands  Tactical roguelike w/ stealth
#
#                                             Icon URL  User Rating Count  \
# 0  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                982
# 1  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                 19
# 2  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                 14
# 3  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                 88
# 4  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                 13
#
#    Price                                   In-app Purchases  \
# 0   0.00  29.99, 19.99, 9.99, 29.99, 29.99, 8.99, 4.99, ...
# 1   0.00                                                NaN
# 2   0.00                                                NaN
# 3   1.99                                                NaN
# 4   3.99                                                NaN
#
#                                          Description           Developer  \
# 0  A Dark Fantasy, Collectible RPG\n\nDarkness ha...        GAMEVIL Inc.
# 1  "This interactive experience is an exploration...  Auroch Digital Ltd
# 2  Same Solitaire game with classic Solitaire run...     Chen Zhong Yuan
# 3  ** Discounted for a limited time **\n\nEver wo...     GG Wizards, LLC
# 4  Fight or sneak your way through hordes of mons...       Luis Regueira
#
#   Age Rating                               Languages       Size Primary Genre  \
# 0        12+  EN, FR, DE, JA, KO, ZH, ES, TH, ZH, VI  894489600         Games
# 1        12+                                      EN  116407296         Games
# 2         4+                                  EN, ZH   50647040         Games
# 3         9+                                      EN   28120064         Games
# 4        12+                                      EN   39915520         Games
#
#                                  Genres Original Release Date  \
# 0         Games, Role Playing, Strategy            2018-03-06
# 1     Games, Simulation, Strategy, News            2013-03-21
# 2  Games, Strategy, Entertainment, Card            2013-04-04
# 3      Games, Utilities, Card, Strategy            2011-05-26
# 4         Games, Role Playing, Strategy            2017-05-19
#
#   Current Version Release Date          Rate
# 0                   2019-07-31  Intermediate
# 1                   2017-06-28  Intermediate
# 2                   2015-04-21          High
# 3                   2019-07-23  Intermediate
# 4                   2019-02-06          High

# %%
def description(df):
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    return summary

# %%
description(dataset)
# Out:
#                             Name          dtypes  Missing  Uniques
# 0                            URL          object        0     5171
# 1                             ID           int64        0     5171
# 2                           Name          object        0     5171
# 3                       Subtitle          object     3749     1399
# 4                       Icon URL          object        0     5171
# 5              User Rating Count           int64        0     1410
# 6                          Price         float64        0       17
# 7               In-app Purchases          object     2039     2052
# 8                    Description          object        0     5099
# 9                      Developer          object        0     3084
# 10                    Age Rating          object        0        4
# 11                     Languages          object       11      580
# 12                          Size           int64        0     5081
# 13                 Primary Genre          object        0       19
# 14                        Genres          object        0      507
# 15         Original Release Date  datetime64[ns]        0     2280
# 16  Current Version Release Date  datetime64[ns]        0     1976
# 17                          Rate          object        0        3

# %%
# Count the number of duplicate rows
dataset.duplicated().sum() # Duplicates =  43
# Out:
# 43

# %%
# Drop duplicate rows
dataset = dataset.drop_duplicates()

# %%
# Count the number of duplicate rows
dataset.duplicated().sum()
# Out:
# 0

# %%
# Print the 'Name' and 'Gender' columns
dataset[['URL','Name','Subtitle','Icon URL','Description']].head()
# Out:
#                                                  URL  \
# 0  https://apps.apple.com/us/app/heir-of-light/id...
# 1  https://apps.apple.com/us/app/endgame-eurasia/...
# 2  https://apps.apple.com/us/app/free-solitaire/i...
# 3  https://apps.apple.com/us/app/draft-trainer/id...
# 4  https://apps.apple.com/us/app/rogue-knight-inf...
#
#                            Name                       Subtitle  \
# 0                 HEIR OF LIGHT               Dark Fantasy RPG
# 1               Endgame:Eurasia                            NaN
# 2               Free Solitaire+                            NaN
# 3                 Draft Trainer                            NaN
# 4  Rogue Knight: Infested Lands  Tactical roguelike w/ stealth
#
#                                             Icon URL  \
# 0  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 1  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                          Description
# 0  A Dark Fantasy, Collectible RPG\n\nDarkness ha...
# 1  "This interactive experience is an exploration...
# 2  Same Solitaire game with classic Solitaire run...
# 3  ** Discounted for a limited time **\n\nEver wo...
# 4  Fight or sneak your way through hordes of mons...

# %%
from sklearn.preprocessing import LabelEncoder

def Feature_Encoder(X,cols):
    for c in cols:
        lbl = LabelEncoder()
        lbl.fit(list(X[c].values))
        X[c] = lbl.transform(list(X[c].values))
    return X


#Feature Encoding
cols=('Name','URL','Icon URL','Description','Subtitle')
dataset=Feature_Encoder(dataset,cols)

# %%
description(dataset)
# Out:
#                             Name          dtypes  Missing  Uniques
# 0                            URL           int32        0     5171
# 1                             ID           int64        0     5171
# 2                           Name           int32        0     5171
# 3                       Subtitle           int32        0     1400
# 4                       Icon URL           int32        0     5171
# 5              User Rating Count           int64        0     1410
# 6                          Price         float64        0       17
# 7               In-app Purchases          object     2025     2052
# 8                    Description           int32        0     5099
# 9                      Developer          object        0     3084
# 10                    Age Rating          object        0        4
# 11                     Languages          object       11      580
# 12                          Size           int64        0     5081
# 13                 Primary Genre          object        0       19
# 14                        Genres          object        0      507
# 15         Original Release Date  datetime64[ns]        0     2280
# 16  Current Version Release Date  datetime64[ns]        0     1976
# 17                          Rate          object        0        3

# %%
# Print the 'Name' and 'Gender' columns
dataset[['URL','Name','Subtitle','Icon URL','Description']]
# Out:
#        URL  Name  Subtitle  Icon URL  Description
# 0     2336  2379       451      2526         2131
# 1     1710  1841      1394      3359         1581
# 2     2010  2123      1394      4863         4082
# 3     1582  1712      1394       491         1941
# 4     3839  3882      1154      1604         3053
# ...    ...   ...       ...       ...          ...
# 5209  3568  3618       316      1288          378
# 5210  2610    85        14       348          935
# 5211  4713  4716      1394       433         1636
# 5212  2549  2652      1394      4252          584
# 5213  3401  3468      1394       768         4912
#
# [5171 rows x 5 columns]

# %%
dataset.isnull().sum()
# Out:
# URL                                0
# ID                                 0
# Name                               0
# Subtitle                           0
# Icon URL                           0
# User Rating Count                  0
# Price                              0
# In-app Purchases                2025
# Description                        0
# Developer                          0
# Age Rating                         0
# Languages                         11
# Size                               0
# Primary Genre                      0
# Genres                             0
# Original Release Date              0
# Current Version Release Date       0
# Rate                               0
# dtype: int64

# %%
dataset[['URL','ID','Subtitle','Icon URL','Name','Description']].nunique()
# Out:
# URL            5171
# ID             5171
# Subtitle       1400
# Icon URL       5171
# Name           5171
# Description    5099
# dtype: int64

# %%
#We deleted all theses columns because they are Unique (Non-Meaningful)
#Subtitle Column almost all cells are Nan values 
#So we will drop this Columns

Columns_To_Deleted = ['URL','ID','Subtitle','Icon URL','Name','Description']
dataset = dataset.drop(columns = Columns_To_Deleted)

# %%
dataset.isnull().sum()
# Out:
# User Rating Count                  0
# Price                              0
# In-app Purchases                2025
# Developer                          0
# Age Rating                         0
# Languages                         11
# Size                               0
# Primary Genre                      0
# Genres                             0
# Original Release Date              0
# Current Version Release Date       0
# Rate                               0
# dtype: int64

# %%
dataset.head()
# Out:
#    User Rating Count  Price  \
# 0                982   0.00
# 1                 19   0.00
# 2                 14   0.00
# 3                 88   1.99
# 4                 13   3.99
#
#                                     In-app Purchases           Developer  \
# 0  29.99, 19.99, 9.99, 29.99, 29.99, 8.99, 4.99, ...        GAMEVIL Inc.
# 1                                                NaN  Auroch Digital Ltd
# 2                                                NaN     Chen Zhong Yuan
# 3                                                NaN     GG Wizards, LLC
# 4                                                NaN       Luis Regueira
#
#   Age Rating                               Languages       Size Primary Genre  \
# 0        12+  EN, FR, DE, JA, KO, ZH, ES, TH, ZH, VI  894489600         Games
# 1        12+                                      EN  116407296         Games
# 2         4+                                  EN, ZH   50647040         Games
# 3         9+                                      EN   28120064         Games
# 4        12+                                      EN   39915520         Games
#
#                                  Genres Original Release Date  \
# 0         Games, Role Playing, Strategy            2018-03-06
# 1     Games, Simulation, Strategy, News            2013-03-21
# 2  Games, Strategy, Entertainment, Card            2013-04-04
# 3      Games, Utilities, Card, Strategy            2011-05-26
# 4         Games, Role Playing, Strategy            2017-05-19
#
#   Current Version Release Date          Rate
# 0                   2019-07-31  Intermediate
# 1                   2017-06-28  Intermediate
# 2                   2015-04-21          High
# 3                   2019-07-23  Intermediate
# 4                   2019-02-06          High

# %%
dataset['In-app Purchases']
# Out:
# 0       29.99, 19.99, 9.99, 29.99, 29.99, 8.99, 4.99, ...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#                               ...
# 5209    1.99, 1.99, 1.99, 1.99, 1.99, 1.99, 2.99, 7.99...
# 5210     2.99, 4.99, 1.99, 2.99, 5.99, 9.99, 11.99, 19.99
# 5211                                                  NaN
# 5212    9.99, 1.99, 4.99, 19.99, 4.99, 4.99, 4.99, 9.9...
# 5213           0.99, 1.99, 0.99, 4.99, 9.99, 19.99, 49.99
# Name: In-app Purchases, Length: 5171, dtype: object

# %%
# Convert each cell into a list of floats, and compute the mean of the list
dataset['In-app Purchases'] = dataset['In-app Purchases'].apply(lambda x: sum([float(i) for i in x.split(',')]) if pd.notnull(x) else x)
# Replace the missing values with the mean of the In-app Purchases column
mean_value = dataset['In-app Purchases'].mean()
dataset['In-app Purchases'] = dataset['In-app Purchases'].fillna(mean_value)

# %%
dataset['In-app Purchases']
# Out:
# 0       307.840000
# 1        61.674269
# 2        61.674269
# 3        61.674269
# 4        61.674269
#            ...
# 5209     53.860000
# 5210     60.920000
# 5211     61.674269
# 5212    121.900000
# 5213     88.930000
# Name: In-app Purchases, Length: 5171, dtype: float64

# %%
dataset
# Out:
#       User Rating Count  Price  In-app Purchases             Developer  \
# 0                   982   0.00        307.840000          GAMEVIL Inc.
# 1                    19   0.00         61.674269    Auroch Digital Ltd
# 2                    14   0.00         61.674269       Chen Zhong Yuan
# 3                    88   1.99         61.674269       GG Wizards, LLC
# 4                    13   3.99         61.674269         Luis Regueira
# ...                 ...    ...               ...                   ...
# 5209             205014   0.99         53.860000      Ndemic Creations
# 5210                252   0.00         60.920000           AFEEL, Inc.
# 5211                 12   0.00         61.674269   Stasis Software LLC
# 5212                578   0.00        121.900000      ZEN Studios Ltd.
# 5213                782   0.00         88.930000  Supervillain Studios
#
#      Age Rating                                          Languages       Size  \
# 0           12+             EN, FR, DE, JA, KO, ZH, ES, TH, ZH, VI  894489600
# 1           12+                                                 EN  116407296
# 2            4+                                             EN, ZH   50647040
# 3            9+                                                 EN   28120064
# 4           12+                                                 EN   39915520
# ...         ...                                                ...        ...
# 5209        12+  EN, FR, DE, IT, JA, KO, NB, PL, PT, RU, ZH, ES...  118793216
# 5210         4+                                         EN, JA, KO   79267840
# 5211         4+                                                 EN   19513344
# 5212         9+                                                 EN  275680256
# 5213         4+                                                 EN   85438464
#
#      Primary Genre                                      Genres  \
# 0            Games               Games, Role Playing, Strategy
# 1            Games           Games, Simulation, Strategy, News
# 2            Games        Games, Strategy, Entertainment, Card
# 3            Games            Games, Utilities, Card, Strategy
# 4            Games               Games, Role Playing, Strategy
# ...            ...                                         ...
# 5209         Games                 Games, Strategy, Simulation
# 5210         Games  Games, Simulation, Strategy, Entertainment
# 5211     Utilities           Utilities, Games, Board, Strategy
# 5212         Games               Games, Strategy, Role Playing
# 5213         Games        Games, Card, Entertainment, Strategy
#
#      Original Release Date Current Version Release Date          Rate
# 0               2018-03-06                   2019-07-31  Intermediate
# 1               2013-03-21                   2017-06-28  Intermediate
# 2               2013-04-04                   2015-04-21          High
# 3               2011-05-26                   2019-07-23  Intermediate
# 4               2017-05-19                   2019-02-06          High
# ...                    ...                          ...           ...
# 5209            2012-05-26                   2019-02-08          High
# 5210            2015-01-11                   2018-04-16          High
# 5211            2012-08-16                   2017-02-21          High
# 5212            2016-06-08                   2017-01-30  Intermediate
# 5213            2012-09-10                   2015-03-14  Intermediate
#
# [5171 rows x 12 columns]

# %%
dataset.isnull().sum()
# Out:
# User Rating Count                0
# Price                            0
# In-app Purchases                 0
# Developer                        0
# Age Rating                       0
# Languages                       11
# Size                             0
# Primary Genre                    0
# Genres                           0
# Original Release Date            0
# Current Version Release Date     0
# Rate                             0
# dtype: int64

# %%
# split the string values into lists of languages
Lang_temp = dataset['Languages'].str.split(',')
print(Lang_temp)

# use explode to convert the list column into separate rows
exploded_Lang = Lang_temp.explode()    #from 5214 to 20429
print(exploded_Lang)

# fill missing values with mode value
mode_value = exploded_Lang.mode()[0]
dataset['Languages'] = dataset['Languages'].fillna(value=mode_value)
# Out:
# 0       [EN,  FR,  DE,  JA,  KO,  ZH,  ES,  TH,  ZH,  VI]
# 1                                                    [EN]
# 2                                               [EN,  ZH]
# 3                                                    [EN]
# 4                                                    [EN]
#                               ...
# 5209    [EN,  FR,  DE,  IT,  JA,  KO,  NB,  PL,  PT,  ...
# 5210                                       [EN,  JA,  KO]
# 5211                                                 [EN]
# 5212                                                 [EN]
# 5213                                                 [EN]
# Name: Languages, Length: 5171, dtype: object
# 0        EN
# 0        FR
# 0        DE
# 0        JA
# 0        KO
#        ...
# 5210     JA
# 5210     KO
# 5211     EN
# 5212     EN
# 5213     EN
# Name: Languages, Length: 20268, dtype: object

# %%
dataset.isnull().any()
# Out:
# User Rating Count               False
# Price                           False
# In-app Purchases                False
# Developer                       False
# Age Rating                      False
# Languages                       False
# Size                            False
# Primary Genre                   False
# Genres                          False
# Original Release Date           False
# Current Version Release Date    False
# Rate                            False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# User Rating Count               0
# Price                           0
# In-app Purchases                0
# Developer                       0
# Age Rating                      0
# Languages                       0
# Size                            0
# Primary Genre                   0
# Genres                          0
# Original Release Date           0
# Current Version Release Date    0
# Rate                            0
# dtype: int64

# %%
dataset
# Out:
#       User Rating Count  Price  In-app Purchases             Developer  \
# 0                   982   0.00        307.840000          GAMEVIL Inc.
# 1                    19   0.00         61.674269    Auroch Digital Ltd
# 2                    14   0.00         61.674269       Chen Zhong Yuan
# 3                    88   1.99         61.674269       GG Wizards, LLC
# 4                    13   3.99         61.674269         Luis Regueira
# ...                 ...    ...               ...                   ...
# 5209             205014   0.99         53.860000      Ndemic Creations
# 5210                252   0.00         60.920000           AFEEL, Inc.
# 5211                 12   0.00         61.674269   Stasis Software LLC
# 5212                578   0.00        121.900000      ZEN Studios Ltd.
# 5213                782   0.00         88.930000  Supervillain Studios
#
#      Age Rating                                          Languages       Size  \
# 0           12+             EN, FR, DE, JA, KO, ZH, ES, TH, ZH, VI  894489600
# 1           12+                                                 EN  116407296
# 2            4+                                             EN, ZH   50647040
# 3            9+                                                 EN   28120064
# 4           12+                                                 EN   39915520
# ...         ...                                                ...        ...
# 5209        12+  EN, FR, DE, IT, JA, KO, NB, PL, PT, RU, ZH, ES...  118793216
# 5210         4+                                         EN, JA, KO   79267840
# 5211         4+                                                 EN   19513344
# 5212         9+                                                 EN  275680256
# 5213         4+                                                 EN   85438464
#
#      Primary Genre                                      Genres  \
# 0            Games               Games, Role Playing, Strategy
# 1            Games           Games, Simulation, Strategy, News
# 2            Games        Games, Strategy, Entertainment, Card
# 3            Games            Games, Utilities, Card, Strategy
# 4            Games               Games, Role Playing, Strategy
# ...            ...                                         ...
# 5209         Games                 Games, Strategy, Simulation
# 5210         Games  Games, Simulation, Strategy, Entertainment
# 5211     Utilities           Utilities, Games, Board, Strategy
# 5212         Games               Games, Strategy, Role Playing
# 5213         Games        Games, Card, Entertainment, Strategy
#
#      Original Release Date Current Version Release Date          Rate
# 0               2018-03-06                   2019-07-31  Intermediate
# 1               2013-03-21                   2017-06-28  Intermediate
# 2               2013-04-04                   2015-04-21          High
# 3               2011-05-26                   2019-07-23  Intermediate
# 4               2017-05-19                   2019-02-06          High
# ...                    ...                          ...           ...
# 5209            2012-05-26                   2019-02-08          High
# 5210            2015-01-11                   2018-04-16          High
# 5211            2012-08-16                   2017-02-21          High
# 5212            2016-06-08                   2017-01-30  Intermediate
# 5213            2012-09-10                   2015-03-14  Intermediate
#
# [5171 rows x 12 columns]

# %%
# Convert Age Rating to string and lowercase
dataset['Age Rating'] = dataset['Age Rating'].astype(str).str.lower()
# Rename column
dataset.rename(columns={'Age Rating': 'Min Age'}, inplace=True)
dataset['Min Age'] = dataset['Min Age'].str.replace('+','').astype(int)
dataset['Min Age']
# Out:
# 0       12
# 1       12
# 2        4
# 3        9
# 4       12
#         ..
# 5209    12
# 5210     4
# 5211     4
# 5212     9
# 5213     4
# Name: Min Age, Length: 5171, dtype: int32

# %%
dataset
# Out:
#       User Rating Count  Price  In-app Purchases             Developer  \
# 0                   982   0.00        307.840000          GAMEVIL Inc.
# 1                    19   0.00         61.674269    Auroch Digital Ltd
# 2                    14   0.00         61.674269       Chen Zhong Yuan
# 3                    88   1.99         61.674269       GG Wizards, LLC
# 4                    13   3.99         61.674269         Luis Regueira
# ...                 ...    ...               ...                   ...
# 5209             205014   0.99         53.860000      Ndemic Creations
# 5210                252   0.00         60.920000           AFEEL, Inc.
# 5211                 12   0.00         61.674269   Stasis Software LLC
# 5212                578   0.00        121.900000      ZEN Studios Ltd.
# 5213                782   0.00         88.930000  Supervillain Studios
#
#       Min Age                                          Languages       Size  \
# 0          12             EN, FR, DE, JA, KO, ZH, ES, TH, ZH, VI  894489600
# 1          12                                                 EN  116407296
# 2           4                                             EN, ZH   50647040
# 3           9                                                 EN   28120064
# 4          12                                                 EN   39915520
# ...       ...                                                ...        ...
# 5209       12  EN, FR, DE, IT, JA, KO, NB, PL, PT, RU, ZH, ES...  118793216
# 5210        4                                         EN, JA, KO   79267840
# 5211        4                                                 EN   19513344
# 5212        9                                                 EN  275680256
# 5213        4                                                 EN   85438464
#
#      Primary Genre                                      Genres  \
# 0            Games               Games, Role Playing, Strategy
# 1            Games           Games, Simulation, Strategy, News
# 2            Games        Games, Strategy, Entertainment, Card
# 3            Games            Games, Utilities, Card, Strategy
# 4            Games               Games, Role Playing, Strategy
# ...            ...                                         ...
# 5209         Games                 Games, Strategy, Simulation
# 5210         Games  Games, Simulation, Strategy, Entertainment
# 5211     Utilities           Utilities, Games, Board, Strategy
# 5212         Games               Games, Strategy, Role Playing
# 5213         Games        Games, Card, Entertainment, Strategy
#
#      Original Release Date Current Version Release Date          Rate
# 0               2018-03-06                   2019-07-31  Intermediate
# 1               2013-03-21                   2017-06-28  Intermediate
# 2               2013-04-04                   2015-04-21          High
# 3               2011-05-26                   2019-07-23  Intermediate
# 4               2017-05-19                   2019-02-06          High
# ...                    ...                          ...           ...
# 5209            2012-05-26                   2019-02-08          High
# 5210            2015-01-11                   2018-04-16          High
# 5211            2012-08-16                   2017-02-21          High
# 5212            2016-06-08                   2017-01-30  Intermediate
# 5213            2012-09-10                   2015-03-14  Intermediate
#
# [5171 rows x 12 columns]

# %% [markdown]
# ### Convert Categorical Data to numeric based on Label(Average User Rating)

# %%
dataset[['Developer','Languages','Primary Genre','Genres']]
# Out:
#                  Developer                                          Languages  \
# 0             GAMEVIL Inc.             EN, FR, DE, JA, KO, ZH, ES, TH, ZH, VI
# 1       Auroch Digital Ltd                                                 EN
# 2          Chen Zhong Yuan                                             EN, ZH
# 3          GG Wizards, LLC                                                 EN
# 4            Luis Regueira                                                 EN
# ...                    ...                                                ...
# 5209      Ndemic Creations  EN, FR, DE, IT, JA, KO, NB, PL, PT, RU, ZH, ES...
# 5210           AFEEL, Inc.                                         EN, JA, KO
# 5211   Stasis Software LLC                                                 EN
# 5212      ZEN Studios Ltd.                                                 EN
# 5213  Supervillain Studios                                                 EN
#
#      Primary Genre                                      Genres
# 0            Games               Games, Role Playing, Strategy
# 1            Games           Games, Simulation, Strategy, News
# 2            Games        Games, Strategy, Entertainment, Card
# 3            Games            Games, Utilities, Card, Strategy
# 4            Games               Games, Role Playing, Strategy
# ...            ...                                         ...
# 5209         Games                 Games, Strategy, Simulation
# 5210         Games  Games, Simulation, Strategy, Entertainment
# 5211     Utilities           Utilities, Games, Board, Strategy
# 5212         Games               Games, Strategy, Role Playing
# 5213         Games        Games, Card, Entertainment, Strategy
#
# [5171 rows x 4 columns]

# %% [markdown]
# ## Preprocess Rate Column

# %%
dataset["Rate"] = dataset["Rate"].replace({"Low": 1, "Intermediate": 2, "High": 3})

# %%
dataset['Developer'] = dataset.groupby('Developer')['Rate'].transform(lambda x: x.mean())
dataset['Languages'] = dataset.groupby('Languages')['Rate'].transform(lambda x: x.mean())
dataset['Primary Genre'] = dataset.groupby('Primary Genre')['Rate'].transform(lambda x: x.mean())
dataset['Genres'] = dataset.groupby('Genres')['Rate'].transform(lambda x: x.mean())
dataset
# Out:
#       User Rating Count  Price  In-app Purchases  Developer  Min Age  \
# 0                   982   0.00        307.840000   2.500000       12
# 1                    19   0.00         61.674269   2.000000       12
# 2                    14   0.00         61.674269   2.666667        4
# 3                    88   1.99         61.674269   2.000000        9
# 4                    13   3.99         61.674269   3.000000       12
# ...                 ...    ...               ...        ...      ...
# 5209             205014   0.99         53.860000   3.000000       12
# 5210                252   0.00         60.920000   2.375000        4
# 5211                 12   0.00         61.674269   3.000000        4
# 5212                578   0.00        121.900000   2.500000        9
# 5213                782   0.00         88.930000   2.000000        4
#
#       Languages       Size  Primary Genre    Genres Original Release Date  \
# 0      2.000000  894489600       2.417940  2.516667            2018-03-06
# 1      2.398240  116407296       2.417940  2.500000            2013-03-21
# 2      2.428571   50647040       2.417940  2.419355            2013-04-04
# 3      2.398240   28120064       2.417940  2.000000            2011-05-26
# 4      2.398240   39915520       2.417940  2.516667            2017-05-19
# ...         ...        ...            ...       ...                   ...
# 5209   3.000000  118793216       2.417940  2.362637            2012-05-26
# 5210   2.521739   79267840       2.417940  2.310345            2015-01-11
# 5211   2.398240   19513344       2.387097  3.000000            2012-08-16
# 5212   2.398240  275680256       2.417940  2.559322            2016-06-08
# 5213   2.398240   85438464       2.417940  2.269231            2012-09-10
#
#      Current Version Release Date  Rate
# 0                      2019-07-31     2
# 1                      2017-06-28     2
# 2                      2015-04-21     3
# 3                      2019-07-23     2
# 4                      2019-02-06     3
# ...                           ...   ...
# 5209                   2019-02-08     3
# 5210                   2018-04-16     3
# 5211                   2017-02-21     3
# 5212                   2017-01-30     2
# 5213                   2015-03-14     2
#
# [5171 rows x 12 columns]

# %%
dataset[['Developer','Languages','Primary Genre','Genres']]
# Out:
#       Developer  Languages  Primary Genre    Genres
# 0      2.500000   2.000000       2.417940  2.516667
# 1      2.000000   2.398240       2.417940  2.500000
# 2      2.666667   2.428571       2.417940  2.419355
# 3      2.000000   2.398240       2.417940  2.000000
# 4      3.000000   2.398240       2.417940  2.516667
# ...         ...        ...            ...       ...
# 5209   3.000000   3.000000       2.417940  2.362637
# 5210   2.375000   2.521739       2.417940  2.310345
# 5211   3.000000   2.398240       2.387097  3.000000
# 5212   2.500000   2.398240       2.417940  2.559322
# 5213   2.000000   2.398240       2.417940  2.269231
#
# [5171 rows x 4 columns]

# %%
# Convert the date columns to datetime format
StartDate = pd.to_datetime(dataset['Original Release Date'])
EndDate = pd.to_datetime(dataset['Current Version Release Date'])

# Create a new column with the difference in days between the two datesP
dataset['Days Since Release'] = (EndDate - StartDate).dt.days

# Drop the original date columns
dataset.drop(columns = ['Original Release Date', 'Current Version Release Date'], inplace=True)

dataset
# Out:
#       User Rating Count  Price  In-app Purchases  Developer  Min Age  \
# 0                   982   0.00        307.840000   2.500000       12
# 1                    19   0.00         61.674269   2.000000       12
# 2                    14   0.00         61.674269   2.666667        4
# 3                    88   1.99         61.674269   2.000000        9
# 4                    13   3.99         61.674269   3.000000       12
# ...                 ...    ...               ...        ...      ...
# 5209             205014   0.99         53.860000   3.000000       12
# 5210                252   0.00         60.920000   2.375000        4
# 5211                 12   0.00         61.674269   3.000000        4
# 5212                578   0.00        121.900000   2.500000        9
# 5213                782   0.00         88.930000   2.000000        4
#
#       Languages       Size  Primary Genre    Genres  Rate  Days Since Release
# 0      2.000000  894489600       2.417940  2.516667     2                 512
# 1      2.398240  116407296       2.417940  2.500000     2                1560
# 2      2.428571   50647040       2.417940  2.419355     3                 747
# 3      2.398240   28120064       2.417940  2.000000     2                2980
# 4      2.398240   39915520       2.417940  2.516667     3                 628
# ...         ...        ...            ...       ...   ...                 ...
# 5209   3.000000  118793216       2.417940  2.362637     3                2449
# 5210   2.521739   79267840       2.417940  2.310345     3                1191
# 5211   2.398240   19513344       2.387097  3.000000     3                1650
# 5212   2.398240  275680256       2.417940  2.559322     2                 236
# 5213   2.398240   85438464       2.417940  2.269231     2                 915
#
# [5171 rows x 11 columns]

# %% [markdown]
# ### Features & Labels

# %%
data_input = dataset.drop(columns = ['Rate'])  # Features
data_output = dataset['Rate']  # Label

# %%
len(dataset.columns)
# Out:
# 11

# %%
def apply_feature_selection(k):
        # Separate features and labels
        features = dataset.drop(columns=['Rate'])
        label = dataset['Rate']

        # Apply feature selection using SelectKBest
        selector = SelectKBest(score_func=f_classif, k=k)
        X_selected = selector.fit_transform(features, label)


        # Get the selected feature names
        selected_feature_names = features.columns[selector.get_support()].tolist()
        # Update the features dataset with the selected features
        features = pd.DataFrame(data=X_selected, columns=selected_feature_names)

        return features, label

# %%
data_input,data_output = apply_feature_selection(5)
data_input
# Out:
#       Developer  Languages         Size  Primary Genre    Genres
# 0      2.500000   2.000000  894489600.0       2.417940  2.516667
# 1      2.000000   2.398240  116407296.0       2.417940  2.500000
# 2      2.666667   2.428571   50647040.0       2.417940  2.419355
# 3      2.000000   2.398240   28120064.0       2.417940  2.000000
# 4      3.000000   2.398240   39915520.0       2.417940  2.516667
# ...         ...        ...          ...            ...       ...
# 5166   3.000000   3.000000  118793216.0       2.417940  2.362637
# 5167   2.375000   2.521739   79267840.0       2.417940  2.310345
# 5168   3.000000   2.398240   19513344.0       2.387097  3.000000
# 5169   2.500000   2.398240  275680256.0       2.417940  2.559322
# 5170   2.000000   2.398240   85438464.0       2.417940  2.269231
#
# [5171 rows x 5 columns]

# %%
data_output
# Out:
# 0       2
# 1       2
# 2       3
# 3       2
# 4       3
#        ..
# 5209    3
# 5210    3
# 5211    3
# 5212    2
# 5213    2
# Name: Rate, Length: 5171, dtype: int64

# %% [markdown]
# ### Train & Test Split

# %%
# Split the data into train, test
X_train, X_test, y_train, y_test = train_test_split(data_input, data_output, test_size=0.2, random_state=0)

# %%
X_train
# Out:
#       Developer  Languages         Size  Primary Genre    Genres
# 3628   3.000000   2.398240   15027200.0       2.529412  3.000000
# 2491   3.000000   2.398240   67420160.0       2.417940  2.500000
# 3262   1.000000   2.398240   10806272.0       2.417940  2.355556
# 2972   2.333333   3.000000  835738624.0       2.417940  2.307692
# 2481   3.000000   2.000000  150199296.0       2.417940  2.446429
# ...         ...        ...          ...            ...       ...
# 4931   2.000000   2.207317    6614449.0       2.417940  2.527778
# 3264   3.000000   2.398240   99400704.0       2.417940  2.250000
# 1653   2.000000   2.398240   43083776.0       2.417940  2.513369
# 2607   3.000000   2.500000  171896832.0       2.417940  2.401163
# 2732   3.000000   2.398240  170715136.0       2.417940  2.537037
#
# [4136 rows x 5 columns]

# %% [markdown]
# ### Feature Scaling using (StandardScaler)

# %%
# # Initialize the scaler
# scaler = StandardScaler()

# # Fit the scaler to the training data
# scaler.fit(X_train)

# # Scale the training, validation, and test data
# X_train_scaled = scaler.transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# # Convert the scaled  data to a dataframe
# X_train = pd.DataFrame(data=X_train_scaled, columns=X_train.columns)
# X_test = pd.DataFrame(data=X_test_scaled, columns=X_test.columns)

# %% [markdown]
# ### Feature Scaling using (MinMaxScaler)

# %%
#Initialize the scaler
scaler = MinMaxScaler()

# Fit the scaler to the training data
scaler.fit(X_train)

# Scale the training, validation, and test data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Convert the scaled  data to a dataframe
X_train = pd.DataFrame(data=X_train_scaled, columns=X_train.columns)
X_test = pd.DataFrame(data=X_test_scaled, columns=X_test.columns)

# %%
X_train
# Out:
#       Developer  Languages      Size  Primary Genre    Genres
# 0      1.074950  -0.072760 -0.482254       2.214716  2.732039
# 1      1.074950  -0.072760 -0.276387       0.051962  0.395010
# 2     -2.586346  -0.072760 -0.498840       0.051962 -0.280132
# 3     -0.145482   2.578028  2.742558       0.051962 -0.503848
# 4      1.074950  -1.827034  0.048876       0.051962  0.144614
# ...         ...        ...       ...            ...       ...
# 4131  -0.755698  -0.913790 -0.515310       0.051962  0.524845
# 4132   1.074950  -0.072760 -0.150726       0.051962 -0.773505
# 4133  -0.755698  -0.072760 -0.372012       0.051962  0.457497
# 4134   1.074950   0.375497  0.134132       0.051962 -0.066961
# 4135   1.074950  -0.072760  0.129488       0.051962  0.568123
#
# [4136 rows x 5 columns]

# %%
import timeit

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
log_C_values = [0.1, 1, 10]
solvers = ['sag', 'liblinear', 'lbfgs']
logreg_models = {}
train_Time = []
print("-------------------Logistic Regression-------------------")

for sol in solvers:
        for C in log_C_values:
            start = timeit.default_timer()
            logreg = LogisticRegression(solver=sol, C=C)
            logreg.fit(X_train, y_train)
            end = timeit.default_timer()
            train_Time.append(end-start)
            y_pred = logreg.predict(X_test)

            logaccuracy = accuracy_score(y_test, y_pred)
            logmodel_name = f'{sol}_{C}'
            logreg_models[logmodel_name] = (logreg, logaccuracy)

            print(f"Solver: {sol}, C: {C}")
            print("----------------------------")
            print("Accuracy score:", logaccuracy)
# Out:
# -------------------Logistic Regression-------------------
# Solver: sag, C: 0.1
# ----------------------------
# Accuracy score: 0.893719806763285
# Solver: sag, C: 1
# ----------------------------
# Accuracy score: 0.8927536231884058
# Solver: sag, C: 10
# ----------------------------
# Accuracy score: 0.8927536231884058
# Solver: liblinear, C: 0.1
# ----------------------------
# Accuracy score: 0.8483091787439614
# Solver: liblinear, C: 1
# ----------------------------
# Accuracy score: 0.8917874396135266
# Solver: liblinear, C: 10
# ----------------------------
# Accuracy score: 0.8917874396135266
# Solver: lbfgs, C: 0.1
# ----------------------------
# Accuracy score: 0.893719806763285
# Solver: lbfgs, C: 1
# ----------------------------
# Accuracy score: 0.8927536231884058
# Solver: lbfgs, C: 10
# ----------------------------
# Accuracy score: 0.8927536231884058

# %%
train_Time
# Out:
# [0.033279199968092144,
#  0.038660400023218244,
#  0.03270010004052892,
#  0.01297910005087033,
#  0.013225500006228685,
#  0.014776900003198534,
#  0.030511500022839755,
#  0.0342604000470601,
#  0.06808040000032634]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Define the number of estimators for the random forest
n_estimators = [100, 200, 300]

# Define the maximum depth for the random forest
max_depths = [None, 10, 20]

rf_models = {}
print("-------------------Random Forest Classifier-------------------")

for n_estimator in n_estimators:
    for max_depth in max_depths:
        rf = RandomForestClassifier(n_estimators=n_estimator, max_depth=max_depth)
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_test)

        rf_accuracy = accuracy_score(y_test, y_pred)
        rf_model_name = f'n_estimators={n_estimator}_max_depth={max_depth}'
        rf_models[rf_model_name] = (rf, rf_accuracy)

        print(f"n_estimators: {n_estimator}, max_depth: {max_depth}")
        print("----------------------------")
        print("Accuracy score:", rf_accuracy)
# Out:
# -------------------Random Forest Classifier-------------------
# n_estimators: 100, max_depth: None
# ----------------------------
# Accuracy score: 0.8608695652173913
# n_estimators: 100, max_depth: 10
# ----------------------------
# Accuracy score: 0.8917874396135266
# n_estimators: 100, max_depth: 20
# ----------------------------
# Accuracy score: 0.8666666666666667
# n_estimators: 200, max_depth: None
# ----------------------------
# Accuracy score: 0.8685990338164251
# n_estimators: 200, max_depth: 10
# ----------------------------
# Accuracy score: 0.8888888888888888
# n_estimators: 200, max_depth: 20
# ----------------------------
# Accuracy score: 0.8647342995169082
# n_estimators: 300, max_depth: None
# ----------------------------
# Accuracy score: 0.8685990338164251
# n_estimators: 300, max_depth: 10
# ----------------------------
# Accuracy score: 0.8879227053140096
# n_estimators: 300, max_depth: 20
# ----------------------------
# Accuracy score: 0.8647342995169082
